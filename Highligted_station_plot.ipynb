# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pprint
matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
df = pd.read_csv('/Users/qni/QADG_Consulting/two_year_clean.csv')
df = df.set_index('time')
#sorted(list(df.columns.unique()))
df[['AV H','AV I','AV J','QUEENS PLAZA','QUEENSBORO PLZ','COURT SQ','103 ST CORONA']]
# Out:
#                     AV H           AV I          AV J  QUEENS PLAZA  \
# time
# 2015-06-13  2.381583e+03    2070.000000  5.171500e+03  9.793167e+03
# 2015-06-20  2.320417e+03    2020.166667  4.959833e+03  8.471250e+03
# 2015-06-27  2.275833e+03    1853.333333  4.870667e+03  8.878833e+03
# 2015-07-04  2.217833e+03    1524.000000  4.643667e+03  8.029667e+03
# 2015-07-11  2.219000e+03    1576.333333  4.700500e+03  8.032333e+03
# 2015-07-18  2.037667e+03    1512.166667  4.562167e+03  8.345833e+03
# 2015-07-25  1.963333e+03    1613.666667  4.524167e+03  8.393667e+03
# 2015-08-01  1.944500e+03    1610.333333  4.446333e+03  7.971000e+03
# 2015-08-08  1.953633e+03    1664.000000  4.503167e+03  7.752500e+03
# 2015-08-15  1.812833e+03    1422.166667  4.322500e+03  7.589333e+03
# 2015-08-22  1.775167e+03    1421.333333  4.242667e+03  6.823000e+03
# 2015-08-29  2.051500e+03    1440.000000  4.429167e+03  7.045333e+03
# 2015-09-05  2.361167e+03    1727.833333  4.657333e+03  6.839167e+03
# ...

# %%
df = df[np.abs(df-df.mean())<=(3*df.std())]
df = df[np.abs(df-df.mean())<=(3*df.std())]
df = df.interpolate()
df = df.rolling(5).mean()
df = pd.DataFrame(index = df.index, columns=['AV H','AV I','AV J','QUEENS PLAZA','QUEENSBORO PLZ','COURT SQ','103 ST CORONA'])

# %%
plt.figure(figsize=(18,10))
df.plot()
plt.xticks(range(0,len(df.index),10),df.index[::10])#,rotation=45)
plt.ylabel("Count")
plt.xlabel("Time")

# %%
# Out:
# <module 'matplotlib.pyplot' from '/Users/qni/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py'>
