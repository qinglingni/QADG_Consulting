# %%
import pandas as pd
df = pd.read_csv("/Users/qni/QADG_Consulting/two_year_clean.csv")
df = df.set_index("time")
df.head()
# Out:
#                     1 AV        103 ST  103 ST CORONA       104 ST  \
# time
# 2015-06-13  22985.833333  23939.666667   17017.833333  2054.833333
# 2015-06-20  22509.500000  23813.000000   18070.833333  2051.166667
# 2015-06-27  21533.000000  22778.500000   17754.333333  1980.333333
# 2015-07-04  21622.166667  21754.500000   17667.500000  1867.500000
# 2015-07-11  20351.500000  21060.333333   17250.166667  1862.666667
#
#                   110 ST        111 ST        116 ST  116 ST COLUMBIA  \
# time
# 2015-06-13  13421.000000  12572.166667  3.305450e+04     11310.333333
# 2015-06-20  13941.666667  12434.000000  3.351883e+04     11367.833333
# 2015-06-27  12641.500000  11860.333333  3.139317e+04     12185.666667
# 2015-07-04  11710.166667  11927.833333  2.702153e+08     12390.666667
# 2015-07-11  11737.833333  11470.000000  2.862133e+04     11865.333333
#
#                  121 ST        125 ST     ...       W 8 ST AQUARIUM  \
# time                                      ...
# 2015-06-13  2236.666667  75598.366667     ...           2416.500000
# 2015-06-20  2212.333333  69919.500000     ...           2660.000000
# 2015-06-27  2179.000000  68806.666667     ...           3319.666667
# 2015-07-04  2103.833333  64599.833333     ...           2521.166667
# 2015-07-11  2061.500000  63196.166667     ...           3477.666667
#
#             WAKEFIELD 241       WALL ST  WESTCHESTER SQ  WHITLOCK AV  \
# time
# 2015-06-13    4905.666667  41503.833333     5697.000000  1481.000000
# 2015-06-20    4845.833333  41569.833333     5524.333333  1593.500000
# 2015-06-27    4818.333333  40741.333333     5302.166667  1530.833333
# 2015-07-04    4458.333333  39400.000000     5008.666667  1545.166667
# 2015-07-11    4461.500000  45772.166667     5140.166667  1598.166667
#
#             WINTHROP ST  WOODHAVEN BLVD  WORLD TRADE CTR      YORK ST  \
# time
# 2015-06-13  6342.666667    24796.333333     12984.666667  7600.833333
# 2015-06-20  6309.500000    24551.500000     13309.166667  7994.833333
# 2015-06-27  6046.000000    24317.000000     13416.500000  7891.166667
# 2015-07-04  5761.166667    22574.166667     13352.666667  7302.833333
# 2015-07-11  5763.166667    22100.500000     13007.166667  7708.166667
#
#               ZEREGA AV
# time
# 2015-06-13  1999.000000
# 2015-06-20  1990.000000
# 2015-06-27  1916.500000
# 2015-07-04  1833.333333
# 2015-07-11  1854.000000
#
# [5 rows x 289 columns]

# %%
# %matplotlib inline
import matplotlib.pylab as plt
import numpy as np

df = df[np.abs(df-df.mean())<=(3*df.std())]
df = df[np.abs(df-df.mean())<=(3*df.std())]
df = df.interpolate()
df = df.rolling(5).mean()

# %%
def plot_col(col):
    plt.figure(figsize=(12,3))
    plt.plot(range(len(df.index)),df[col])
    plt.xticks(range(0,len(df.index),10),df.index[::10])#,rotation=45)
    plt.ylabel("Count")
    plt.xlabel("Time")
    plt.title(col)
    return plt

# %%
plot_col('AV H')
# Out:
# <module 'matplotlib.pylab' from '/Users/qni/anaconda3/lib/python3.6/site-packages/matplotlib/pylab.py'>

# %%
plot_col("AV J")
# Out:
# <module 'matplotlib.pylab' from '/Users/qni/anaconda3/lib/python3.6/site-packages/matplotlib/pylab.py'>

# %%
plot_col("WALL ST")
# Out:
# <module 'matplotlib.pylab' from '/Users/guoli/anaconda2/lib/python2.7/site-packages/matplotlib/pylab.pyc'>

# %%
plot_col("ZEREGA AV")
# Out:
# <module 'matplotlib.pylab' from '/Users/guoli/anaconda2/lib/python2.7/site-packages/matplotlib/pylab.pyc'>
